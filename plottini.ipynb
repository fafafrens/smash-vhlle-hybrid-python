# %%
import hybrid_lib as hl
import matplotlib.pyplot as plt
import plot_lib as pl

# %%
filename="baryon_nocent20-30_params:etaS_0.001_e_crit_0.5_superMC:sNN_200_eta0_2.5_sigmaeta_0.5_w_0.8" +"/" +"Afterburner/particle_lists.oscar"

# %%
plt.plot(*pl.pseudorapidity_distribution_simple(filename,"charged"))
# Out:
# analysing charged particles

# %%
plt.plot(*pl.pt_distribution_simple(filename,"charged"))
plt.yscale("log")
# Out:
# analysing charged particles

# %%
plt.plot(*pl.nth_flow_pt_simple(filename,"charged"))
# Out:
# analysing charged particles

# %%
plt.plot(*pl.nth_flow_eta_simple(filename,"charged",number_of_bins=10,n_order=1))
# Out:
# analysing charged particles
